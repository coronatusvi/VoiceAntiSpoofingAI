# %%
# Đường dẫn tệp đầu vào và đầu ra
input_file = "/home/coronatusvi/Documents/GITHUB/VoiceAntiSpoofingAI/LA_Original/ASVspoof2019_LA_asv_scores/ASVspoof2019.LA.asv.eval.gi.trl.scores.txt"
output_file = "/home/coronatusvi/Documents/GITHUB/VoiceAntiSpoofingAI/VN/SPOOF/LA/ASVspoof2019_LA_asv_scores/ASVspoof2019.LA.asv.eval.gi.trl.scores.txt"

# Các từ khóa cần giữ lại
keywords = ["A01", "A02", "A03", "A05", "A06", "A08", "A10", "A12", "A15", "A19", "bonafide"]

# Đọc tệp và lọc các dòng
with open(input_file, "r") as infile, open(output_file, "w") as outfile:
    for line in infile:
        if any(keyword in line for keyword in keywords):
            outfile.write(line)

# %%
# Đường dẫn tệp đầu vào và đầu ra
input_file = "/home/coronatusvi/Documents/GITHUB/VoiceAntiSpoofingAI/LA_Original/ASVspoof2019_LA_asv_scores/ASVspoof2019.LA.asv.dev.gi.trl.scores.txt"
output_file = "/home/coronatusvi/Documents/GITHUB/VoiceAntiSpoofingAI/VN/SPOOF/LA/ASVspoof2019_LA_asv_scores/ASVspoof2019.LA.asv.dev.gi.trl.scores.txt"

# Các từ khóa cần giữ lại
keywords = ["A01", "A02", "A03", "A05", "A06", "A08", "A10", "A12", "A15", "A19", "bonafide"]

# Đọc tệp và lọc các dòng
with open(input_file, "r") as infile, open(output_file, "w") as outfile:
    for line in infile:
        if any(keyword in line for keyword in keywords):
            outfile.write(line)
